# %% [markdown]
# <a href="https://colab.research.google.com/github/dzejkopjarosinski/FakeNews-Detector/blob/main/FakeNewsDetector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' The necessary files can be downloaded from 
    news.csv - https://drive.google.com/u/0/uc?id=1ekbxlI_GdF3H_XHS8U2Csj5q5AhNXhMp&export=download
    glove.6B.50d.txt - https://drive.google.com/file/d/1ekbxlI_GdF3H_XHS8U2Csj5q5AhNXhMp/view
'''
# Out:
# ' The necessary files can be downloaded from \n    news.csv - https://drive.google.com/u/0/uc?id=1ekbxlI_GdF3H_XHS8U2Csj5q5AhNXhMp&export=download\n    glove.6B.50d.txt - https://drive.google.com/file/d/1ekbxlI_GdF3H_XHS8U2Csj5q5AhNXhMp/view\n'

# %%
# Imports
import numpy as np
import pandas as pd
import json
import csv
import random
  
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
  
import pprint
import tensorflow.compat.v1 as tf
from tensorflow.python.framework import ops
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
tf.disable_eager_execution()

# %%
# Reading the data
data = pd.read_csv("news.csv")
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
data = data.drop(["Unnamed: 0"], axis=1)
data.head(5)
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
# encoding the labels
le = preprocessing.LabelEncoder()
le.fit(data['label'])
data['label'] = le.transform(data['label'])

# %%
embedding_dim = 50
max_length = 54
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
training_size = 3000
test_portion = .1

# %%
title = []
text = []
labels = []
for x in range(training_size):
	title.append(data['title'][x])
	text.append(data['text'][x])
	labels.append(data['label'][x])

# %%
tokenizer1 = Tokenizer()
tokenizer1.fit_on_texts(title)
word_index1 = tokenizer1.word_index
vocab_size1 = len(word_index1)
sequences1 = tokenizer1.texts_to_sequences(title)
padded1 = pad_sequences(
    sequences1,  padding=padding_type, truncating=trunc_type)
split = int(test_portion * training_size)
training_sequences1 = padded1[split:training_size]
test_sequences1 = padded1[0:split]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
embeddings_index = {}
with open('glove.6B.50d.txt') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
  
# Generating embeddings
embeddings_matrix = np.zeros((vocab_size1+1, embedding_dim))
for word, i in word_index1.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size1+1, embedding_dim,
                              input_length=max_length, weights=[
                                  embeddings_matrix],
                              trainable=False),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',
              optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 54, 50)            377600
#
#  dropout_1 (Dropout)         (None, 54, 50)            0
#
#  conv1d_1 (Conv1D)           (None, 50, 64)            16064
#
#  max_pooling1d_1 (MaxPooling  (None, 12, 64)           0
#  1D)
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 426,753
# Trainable params: 49,153
# Non-trainable params: 377,600
# _________________________________________________________________

# %%
num_epochs = 50

training_padded = np.array(training_sequences1)
training_labels = np.array(training_labels)
testing_padded = np.array(test_sequences1)
testing_labels = np.array(test_labels)

history = model.fit(training_padded, training_labels,
					epochs=num_epochs,
					validation_data=(testing_padded,
									testing_labels),
					verbose=2)
# Out:
# Train on 2700 samples, validate on 300 samples
# Epoch 1/50
# 2700/2700 - 2s - loss: 0.0342 - accuracy: 0.9881 - val_loss: 1.0684 - val_accuracy: 0.7400 - 2s/epoch - 771us/sample
# Epoch 2/50
# 2700/2700 - 2s - loss: 0.0366 - accuracy: 0.9893 - val_loss: 0.8541 - val_accuracy: 0.7667 - 2s/epoch - 752us/sample
# Epoch 3/50
# 2700/2700 - 2s - loss: 0.0403 - accuracy: 0.9819 - val_loss: 1.0736 - val_accuracy: 0.7667 - 2s/epoch - 866us/sample
# Epoch 4/50
# 2700/2700 - 3s - loss: 0.0479 - accuracy: 0.9852 - val_loss: 0.9123 - val_accuracy: 0.7533 - 3s/epoch - 1ms/sample
# Epoch 5/50
# 2700/2700 - 2s - loss: 0.0305 - accuracy: 0.9893 - val_loss: 1.0025 - val_accuracy: 0.7700 - 2s/epoch - 763us/sample
# Epoch 6/50
# 2700/2700 - 2s - loss: 0.0331 - accuracy: 0.9878 - val_loss: 1.0404 - val_accuracy: 0.7533 - 2s/epoch - 751us/sample
# Epoch 7/50
# 2700/2700 - 2s - loss: 0.0315 - accuracy: 0.9896 - val_loss: 1.1348 - val_accuracy: 0.7600 - 2s/epoch - 758us/sample
# Epoch 8/50
# 2700/2700 - 2s - loss: 0.0338 - accuracy: 0.9874 - val_loss: 1.1549 - val_accuracy: 0.7667 - 2s/epoch - 760us/sample
# Epoch 9/50
# 2700/2700 - 3s - loss: 0.0399 - accuracy: 0.9863 - val_loss: 1.0078 - val_accuracy: 0.7633 - 3s/epoch - 1ms/sample
# Epoch 10/50
# 2700/2700 - 2s - loss: 0.0401 - accuracy: 0.9859 - val_loss: 1.0139 - val_accuracy: 0.7233 - 2s/epoch - 903us/sample
# Epoch 11/50
# 2700/2700 - 2s - loss: 0.0388 - accuracy: 0.9844 - val_loss: 1.2594 - val_accuracy: 0.7133 - 2s/epoch - 757us/sample
# Epoch 12/50
# 2700/2700 - 2s - loss: 0.0401 - accuracy: 0.9856 - val_loss: 1.0356 - val_accuracy: 0.7467 - 2s/epoch - 757us/sample
# Epoch 13/50
# 2700/2700 - 2s - loss: 0.0350 - accuracy: 0.9867 - val_loss: 1.0203 - val_accuracy: 0.7267 - 2s/epoch - 757us/sample
# Epoch 14/50
# 2700/2700 - 2s - loss: 0.0333 - accuracy: 0.9893 - val_loss: 0.9467 - val_accuracy: 0.7367 - 2s/epoch - 743us/sample
# Epoch 15/50
# 2700/2700 - 3s - loss: 0.0332 - accuracy: 0.9878 - val_loss: 0.8959 - val_accuracy: 0.7500 - 3s/epoch - 1ms/sample
# Epoch 16/50
# 2700/2700 - 2s - loss: 0.0452 - accuracy: 0.9844 - val_loss: 0.9366 - val_accuracy: 0.7367 - 2s/epoch - 753us/sample
# Epoch 17/50
# 2700/2700 - 2s - loss: 0.0358 - accuracy: 0.9893 - val_loss: 0.9703 - val_accuracy: 0.7467 - 2s/epoch - 758us/sample
# Epoch 18/50
# 2700/2700 - 2s - loss: 0.0423 - accuracy: 0.9852 - val_loss: 1.0097 - val_accuracy: 0.7533 - 2s/epoch - 757us/sample
# Epoch 19/50
# 2700/2700 - 2s - loss: 0.0299 - accuracy: 0.9878 - val_loss: 1.3831 - val_accuracy: 0.7433 - 2s/epoch - 758us/sample
# Epoch 20/50
# 2700/2700 - 2s - loss: 0.0386 - accuracy: 0.9856 - val_loss: 1.0584 - val_accuracy: 0.7367 - 2s/epoch - 854us/sample
# Epoch 21/50
# 2700/2700 - 3s - loss: 0.0338 - accuracy: 0.9867 - val_loss: 1.1356 - val_accuracy: 0.7367 - 3s/epoch - 1ms/sample
# Epoch 22/50
# 2700/2700 - 2s - loss: 0.0290 - accuracy: 0.9911 - val_loss: 1.1578 - val_accuracy: 0.7400 - 2s/epoch - 754us/sample
# Epoch 23/50
# 2700/2700 - 2s - loss: 0.0421 - accuracy: 0.9885 - val_loss: 0.9733 - val_accuracy: 0.7233 - 2s/epoch - 757us/sample
# Epoch 24/50
# 2700/2700 - 2s - loss: 0.0355 - accuracy: 0.9878 - val_loss: 1.0040 - val_accuracy: 0.7333 - 2s/epoch - 745us/sample
# Epoch 25/50
# 2700/2700 - 2s - loss: 0.0403 - accuracy: 0.9844 - val_loss: 1.1796 - val_accuracy: 0.7467 - 2s/epoch - 753us/sample
# Epoch 26/50
# 2700/2700 - 3s - loss: 0.0320 - accuracy: 0.9893 - val_loss: 1.1755 - val_accuracy: 0.7433 - 3s/epoch - 1ms/sample
# Epoch 27/50
# 2700/2700 - 2s - loss: 0.0260 - accuracy: 0.9900 - val_loss: 1.1543 - val_accuracy: 0.7167 - 2s/epoch - 925us/sample
# Epoch 28/50
# 2700/2700 - 2s - loss: 0.0313 - accuracy: 0.9878 - val_loss: 1.0102 - val_accuracy: 0.7467 - 2s/epoch - 749us/sample
# Epoch 29/50
# 2700/2700 - 2s - loss: 0.0237 - accuracy: 0.9911 - val_loss: 1.1842 - val_accuracy: 0.7533 - 2s/epoch - 744us/sample
# Epoch 30/50
# 2700/2700 - 2s - loss: 0.0342 - accuracy: 0.9874 - val_loss: 1.0736 - val_accuracy: 0.7567 - 2s/epoch - 742us/sample
# Epoch 31/50
# 2700/2700 - 2s - loss: 0.0279 - accuracy: 0.9885 - val_loss: 1.1106 - val_accuracy: 0.7400 - 2s/epoch - 745us/sample
# Epoch 32/50
# 2700/2700 - 3s - loss: 0.0356 - accuracy: 0.9874 - val_loss: 1.2321 - val_accuracy: 0.7367 - 3s/epoch - 1ms/sample
# Epoch 33/50
# 2700/2700 - 2s - loss: 0.0311 - accuracy: 0.9896 - val_loss: 1.0740 - val_accuracy: 0.7433 - 2s/epoch - 756us/sample
# Epoch 34/50
# 2700/2700 - 2s - loss: 0.0265 - accuracy: 0.9907 - val_loss: 1.2466 - val_accuracy: 0.7500 - 2s/epoch - 743us/sample
# Epoch 35/50
# 2700/2700 - 2s - loss: 0.0303 - accuracy: 0.9907 - val_loss: 1.1201 - val_accuracy: 0.7300 - 2s/epoch - 754us/sample
# Epoch 36/50
# 2700/2700 - 2s - loss: 0.0496 - accuracy: 0.9822 - val_loss: 1.0152 - val_accuracy: 0.7500 - 2s/epoch - 760us/sample
# Epoch 37/50
# 2700/2700 - 2s - loss: 0.0245 - accuracy: 0.9896 - val_loss: 1.2640 - val_accuracy: 0.7600 - 2s/epoch - 773us/sample
# Epoch 38/50
# 2700/2700 - 3s - loss: 0.0402 - accuracy: 0.9837 - val_loss: 1.1131 - val_accuracy: 0.7367 - 3s/epoch - 1ms/sample
# Epoch 39/50
# 2700/2700 - 2s - loss: 0.0265 - accuracy: 0.9900 - val_loss: 1.0883 - val_accuracy: 0.7467 - 2s/epoch - 760us/sample
# Epoch 40/50
# 2700/2700 - 2s - loss: 0.0371 - accuracy: 0.9885 - val_loss: 1.0478 - val_accuracy: 0.7133 - 2s/epoch - 747us/sample
# Epoch 41/50
# 2700/2700 - 2s - loss: 0.0283 - accuracy: 0.9881 - val_loss: 1.0092 - val_accuracy: 0.7600 - 2s/epoch - 750us/sample
# Epoch 42/50
# 2700/2700 - 2s - loss: 0.0444 - accuracy: 0.9826 - val_loss: 1.0097 - val_accuracy: 0.7467 - 2s/epoch - 752us/sample
# Epoch 43/50
# 2700/2700 - 3s - loss: 0.0273 - accuracy: 0.9907 - val_loss: 0.8939 - val_accuracy: 0.7600 - 3s/epoch - 984us/sample
# Epoch 44/50
# 2700/2700 - 3s - loss: 0.0363 - accuracy: 0.9874 - val_loss: 1.0143 - val_accuracy: 0.7533 - 3s/epoch - 1ms/sample
# Epoch 45/50
# 2700/2700 - 2s - loss: 0.0353 - accuracy: 0.9878 - val_loss: 0.9995 - val_accuracy: 0.7600 - 2s/epoch - 752us/sample
# Epoch 46/50
# 2700/2700 - 2s - loss: 0.0308 - accuracy: 0.9867 - val_loss: 0.9639 - val_accuracy: 0.7600 - 2s/epoch - 762us/sample
# Epoch 47/50
# 2700/2700 - 2s - loss: 0.0321 - accuracy: 0.9893 - val_loss: 1.1384 - val_accuracy: 0.7567 - 2s/epoch - 760us/sample
# Epoch 48/50
# 2700/2700 - 2s - loss: 0.0323 - accuracy: 0.9896 - val_loss: 1.3564 - val_accuracy: 0.7333 - 2s/epoch - 764us/sample
# Epoch 49/50
# 2700/2700 - 3s - loss: 0.0376 - accuracy: 0.9852 - val_loss: 1.0208 - val_accuracy: 0.7467 - 3s/epoch - 1ms/sample
# Epoch 50/50
# 2700/2700 - 2s - loss: 0.0166 - accuracy: 0.9926 - val_loss: 1.3690 - val_accuracy: 0.7333 - 2s/epoch - 780us/sample

# %%
# sample text to check if fake or not
X = "Karry to go to France in gesture of sympathy"

# detection
sequences = tokenizer1.texts_to_sequences([X])[0]
sequences = pad_sequences([sequences], maxlen=54,
						padding=padding_type,
						truncating=trunc_type)
if(model.predict(sequences, verbose=0)[0][0] >= 0.5):
	print("This news is True")
else:
	print("This news is false")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# This news is True
